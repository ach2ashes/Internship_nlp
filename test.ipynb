# %%
from text_preprocessing import spacy_preprocessing 
from ner import ner_spacy,find_imo,find_swift,ner_dicts
from highlight_pdf import output

# %%
def charge_text(text_file):
    file = text_file
    f=open(file,'r',encoding='utf8')
    text= f.read()
    return text

def get_entites(text):
    """
    Text is the text from wich we extract the entities
    """ 
    preprocessed_text = spacy_preprocessing(text,lowercase=True,punctuation=True)
    ents = list(ner_spacy(preprocessed_text)[0])
    ents.extend(find_imo(text))
    ents.extend(find_swift(text))
    ents.extend(ner_dicts(text,"postgresql://postgres:achraf@localhost:5432/ner_dicts","ports_banks_ships"))
    return ents

def test(text_file,pdf):
    text = charge_text(text_file)
    text_ents = get_entites(text)
    output(pdf)
    return "pdf highlighté, entité dans le texte sont {}".format(text_ents)

# %%
test("C://Users/PC2//Downloads//26964649.txt","C://Users/PC2//Downloads//26964649.pdf")
# Out:
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# C:\Users\PC2\AppData\Roaming\Python\Python39\site-packages\spacy\pipeline\lemmatizer.py:211: UserWarning: [W108] The rule-based lemmatizer did not find POS annotation for one or more tokens. Check that your pipeline includes components that assign token.pos, typically 'tagger'+'attribute_ruler' or 'morphologizer'.
#   warnings.warn(Warnings.W108)
# c:\Users\PC2\anaconda3\lib\site-packages\spaczz\matcher\tokenmatcher.py:115: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   matches = matcher(doc)
# 'pdf highlighté, entité dans le texte sont [2022, 96, 20, 10, mufg sank, 3, 480, nagoya aichi  , japan, generale, 1, banques sa  df1, 20500, morocco attn  , sec, 20500, morocco, ncgn ma  cas  cas  bay tine, 150  1068112, 05 kg, 41  dhl, iid, 25, 7012, 2lma20500, 42000000, nl, 4600 0098, 7532, 9 496, 22, mufg bank  ltd, 21, 24, nishiki, nagoya, 460, 8660, japan, ref, 1058112 date, 2022, 05, 20, generale, banques sa  df1, jpy, 35, 674  000, 00, 20500, 35, 674  000, 00, morocco attn  , sec, 0522438888, days, 61, generale, 55  boulevard, morocco, 2022, 04, 22, 2022, 08, 08, 2022, 05, 10, toyota, 35, 674  000, 00, anb, 7, 13, jpy, japan, generale, 20, 2022, 1, 2, 3, 4, 06229, 1581058112, 3, toyota, 2, cho  kariya, 448, 8671, japan, 4, 111, 11500 km, 500, nr131418, 008, 4, 80, l, fngopcas, 501, fab bha, 4, nwk, bill lading  , nagoya, nagoya, 20, toyota, 27, 2022, 02, 08, 85206, 110, 192203, 9, oooascdr00079125, 2  4  4  epr84548  j, 20, 77660, 173060, 20, nagoya, nagoya, 3, article 24  nyk line, valorem, wil, article 1b  30  mr  fdf84548  shipper  , toyota, 2, cho  kariya, 448, 8671, japan, generale, 111 km, 11500 km, nr13, no001524502000008, 10, 500, 1418, geean, bill lading  non, 8111, b111, nagoya, nagoya, 20, toyota, 08, 3, 85206, 110, 192203, 9, 00043cdi00079125, 3, 20, 173060, 4, 20, 2022, nagoya nagoya, 3, article 24, 4, valorem, article 18  30  toyota  , 2, cho  kariya, aichi pref  , gag2ge67i, cti, japan, year  2022, 1tt, 500, 27, 2022, 20, toyota, f22ho24, 2022, 0208, no00043cd1007125, 111 km, 500, nagoya, japan, morocco, 22, 2022, 4, 10, 2022, toyota, 20, fob nagoya  , japan, 31184000  freight 4490000, ge, 2, toyota, 40at, 11, 2022, toyota, 6, 6, 8  mn, 5, 4, 