# %%
from text_preprocessing import spacy_preprocessing 
from ner import ner_spacy,find_imo,find_swift,ner_dicts
from highlight_pdf import output,find_ent, pdf_to_base64,base64_to_pdf
import os
import pathlib
import warnings
warnings.filterwarnings('ignore')
import time

# %%
def charge_text(text_file):
    file = text_file
    f=open(file,'r',encoding='utf8')
    text= f.read()
    return text

def get_entites(text):
    """
    Text is the text from wich we extract the entities
    """ 
    preprocessed_text = spacy_preprocessing(text,lowercase=True,punctuation=True)
    ents = list(ner_spacy(preprocessed_text)[0])
    ents.extend(find_imo(text))
    ents.extend(find_swift(text))
    ents.extend(ner_dicts(text,"postgresql://postgres:achraf@localhost:5432/ner_dicts","ports_banks_ships"))
    return ents

def test(text_file,pdf):
    text = charge_text(text_file)
    text_ents = get_entites(text)
    output(pdf,".//output.pdf")
    return "pdf highlighté, entité dans le texte sont {}".format(text_ents)

# %%
def unique_ents(text):
    ents = get_entites(text)
    l=[ent.text for ent in ents]
    return list(set(l))

# %%
find_ent("C://Users//PC2//Downloads//62214199.pdf")

# %%
output("C://Users//PC2//Downloads//62214199.pdf",".//outpu.pdf")
# Out:
# MH las,
# 2344669
# whi
# Bs SOCIETE GENERALE
# CREDIT DOCUMENTAIRE
# _ ch
# ;
# DEMANDE D’OUVERTURE
# ~
# t
# Date
# :
# —
#
#
#
#
#
#
#
# Téléphone
# :
# Fax
# |
# Télex
# compte N°
# (Gd |
# Osi 06 2
# oO
#
#
#
# Suivant instructions ci-dessous et lignes marquées d’une croix, veuillez ouvrir pour notre compte un crédit documentaire
# LJ Révocable
# Bt] lrrévocable
# [7] Transférable
# Par [(_] Coiurrier
# (-] Succinct
# [eo] Confirmé
# ] Télex
# Lj Entier
# LJ Non confirmé
#
#
#
#
#
#
#
# Montant
#
# \
#
#
# ar paiement a vue
# (1)
# Par pai
# a
# Q
# lL Par paiement différé a
# 9
# jours
# [1 De vue
# [_]
# Par acceptation par votre correspondant de traite a_________ jours
# [PY De la date d’expédition
#
#
#
#
#
#
#
#
# Expéditions partielles
# Autorisées
# [—] Non autorisées
# Expédition de
# :
# Transbordement
# Autorisé
# [J Non autorisé
# A destination de
# :
# Au plus tard le :_,
#
#
# oO Départ usine
# ras
# )6=sCros:«S(CéC cA
# «6c
# )6=C ce
# dDcrr 2 ceh
#
#
#
#
#
# :
# ...

# %%
def batch_ner(dir_path):
    for root , dirpath,filenames in os.walk(dir_path):
        files_to_ner =[os.path.join(root,file) for file in filenames] 
        for i,file in enumerate(files_to_ner):
            if ".pdf" in file:
                if not os.path.exists(root+"//DOSSIER_NER_RESULT"):
                    os.mkdir(root+"//DOSSIER_NER_RESULT")
                output(file,str(root+"//DOSSIER_NER_RESULT//"+str(i)+".pdf"))
        print(root+" est traité")

# %%
batch_ner("C://Users//PC2//Downloads//ner")
# Out:
# ef
# a
#
# EXPRESS WORLDWIDE [) © X07
# an
# 2022-96-20 MYDHL+ 1.0 f 3008217
# From: MUFG SANK LTD.
# Origin:
# Expoat! ‘BEC
# \-!
# ISHIK)
# .
# aaa
# 3-CHOME,
# NGO
#
#
#
# 480-8680 NAGOYA AICHI
# Japan
# Tre
# : SOCIETE GENERALE MAROCAINE BE
# Contact:
# 1
# BANQUES S.A. / D.F.1. IMMEUBLE
# ASE CRNA
# ALLIANCES BLD YACOUB EL MANSOUR
# ET ANGLE RUE ENNARJIS 20500
# CASABLANCA MOROCCO ATTN:IMPORT SEC.
# 20500 CASABLANCA
# L. Morocco
# _t
# NCGN MA-CAS-CAS
# .
# Bay
# Tine
# Peo/Shpt Welght
# Place
# Ref: 150-1068112 B+
# 0.5 kg
# 4/1
# DHL Rxpreee Terms and Conditions of Carciage apply (www.dhi.coctieniexpreesieninpind/ehing!ne_
# advices. him),
# Contants: Documents -
# Lt lid
# | iid
# | |
# _—
# WA’ YBILL 25 9283 7012
# WM a
# (2L)MA20500+42000000
# NL
# (J) JDO1 4600 0098 6107 7532
#
#
#
# ----------------
# ...

# %%
x = pdf_to_base64("C://Users/PC2/Downloads/yann.pdf")

# %%
base64_to_pdf(x)
# Out:
# './/out.pdf'

# %%
for i in (ner_spacy(' aw prod et slooll  engagement importation1   also  yl ls   1   royaume maroc  declaration importation  al jis  yl gelall yaill  az sbell ojsladl  alsell ajb49ii  licence importation  aber  vl you sill  ministere charge commerce exterieur  ortateur  2ygismallladresse  ulgill  4 24000 casablanca    genpharma  ldentifiant fiscal  1022281  ywladl psll  téléphone   44111111  7414111111  z atlgll  taxe professionnel  asigoll poll  in degré rc  2769  bol dguall 3       courrier électronique   tynig sivt wy   centre rc  17  syd jouull 55       adilzanfarigenpharmama  iexpediteur  us pjsibureau douanier  p02  xisell  zim laboratorie ltd  caser  nouasser  fret301   montant totat devise  agizl no  alell egonclpay origine  laie   allt  montant total   45 50000 dollar usa   inde   fob  36 90000  fret  8 60000    imodalité paiement  sloyi aaaspays provenance  pra   all  reglement credoc  inde   condition tivraison  prluill log u4n  nomenclatur douaniére  oad  drow  6d ps  ll  2942000000  carriagepaid  régime douanier  wsyoall elladi  mise consommation  désignation commercial marchandise  ssulaall aalull awlpoid net  2000  yadlall oi   omeprazole  unité complémentaire   kgm  ddesall clargll  date  cachet signatur  importateur  anigi 9 2ygtuoll wll  alll  in degré date enregistrement2    2  lawl gyl 23   validité  2    lall  2022100000001014133 21062022  dur  21062022   ve    21122022  taire   qd ellagl sl   aur ylel ayladl aalsoll ajljs sur l jl3  aul eligl  glog garall lull  avis département technique  décision ministére charger commerce extérieur  banque domiciliataire  numéro rib bancaire  022780000140000506206974  banque  sgmb  numéro domiciliation  1674096  imputation douaniere  et s poz  egwjll  wisol joy  edgul  alu  yall lay  abs od   dasa  gul  ayosji  anil   1  rayer mention inutile   1  dadoll sll wba  format 210 millimètre x 297 millimètre   2  az ylali alah aalsall ayliglh lol ')[0]) :
    print(i.label_)
# Out:
# PERSON
# PERSON
# GPE
# PERSON
# PRODUCT
# ORG
# ORG
# PERSON
# ORG
# ORG
# ORG
# PERSON
# PERSON
# ORG
# PRODUCT
# PERSON
